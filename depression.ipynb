# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv', sep = '\t')
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  screensize  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...           1
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...           2
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...           2
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...           2
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...           2
#
#    uniquenetworklocation  hand  religion  orientation  race  voted  married  \
# 0                      1     1        12            1    10      2        1
# 1                      1     2         7            0    70      2        1
# 2                      1     1         4            3    60      1        1
# 3                      1     2         4            5    70      2        1
# 4                      2     3        10            1    10      2        1
#
#    familysize       major
# 0           2         NaN
# 1           4         NaN
# 2           3         NaN
# 3           5     biology
# 4           4  Psychology
#
# [5 rows x 172 columns]

# %%
qlist = []
for i in range(1,43):
    qlist.append(f'Q{i}A')

# %%
columns = data.columns.values.tolist()
print(columns)
# Out:
# ['Q1A', 'Q1I', 'Q1E', 'Q2A', 'Q2I', 'Q2E', 'Q3A', 'Q3I', 'Q3E', 'Q4A', 'Q4I', 'Q4E', 'Q5A', 'Q5I', 'Q5E', 'Q6A', 'Q6I', 'Q6E', 'Q7A', 'Q7I', 'Q7E', 'Q8A', 'Q8I', 'Q8E', 'Q9A', 'Q9I', 'Q9E', 'Q10A', 'Q10I', 'Q10E', 'Q11A', 'Q11I', 'Q11E', 'Q12A', 'Q12I', 'Q12E', 'Q13A', 'Q13I', 'Q13E', 'Q14A', 'Q14I', 'Q14E', 'Q15A', 'Q15I', 'Q15E', 'Q16A', 'Q16I', 'Q16E', 'Q17A', 'Q17I', 'Q17E', 'Q18A', 'Q18I', 'Q18E', 'Q19A', 'Q19I', 'Q19E', 'Q20A', 'Q20I', 'Q20E', 'Q21A', 'Q21I', 'Q21E', 'Q22A', 'Q22I', 'Q22E', 'Q23A', 'Q23I', 'Q23E', 'Q24A', 'Q24I', 'Q24E', 'Q25A', 'Q25I', 'Q25E', 'Q26A', 'Q26I', 'Q26E', 'Q27A', 'Q27I', 'Q27E', 'Q28A', 'Q28I', 'Q28E', 'Q29A', 'Q29I', 'Q29E', 'Q30A', 'Q30I', 'Q30E', 'Q31A', 'Q31I', 'Q31E', 'Q32A', 'Q32I', 'Q32E', 'Q33A', 'Q33I', 'Q33E', 'Q34A', 'Q34I', 'Q34E', 'Q35A', 'Q35I', 'Q35E', 'Q36A', 'Q36I', 'Q36E', 'Q37A', 'Q37I', 'Q37E', 'Q38A', 'Q38I', 'Q38E', 'Q39A', 'Q39I', 'Q39E', 'Q40A', 'Q40I', 'Q40E', 'Q41A', 'Q41I', 'Q41E', 'Q42A', 'Q42I', 'Q42E', 'country', 'source', 'introelapse', 'testelapse', 'surveyelapse', 'TIPI1', 'TIPI2', 'TIPI3', 'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10', 'VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6', 'VCL7', 'VCL8', 'VCL9', 'VCL10', 'VCL11', 'VCL12', 'VCL13', 'VCL14', 'VCL15', 'VCL16', 'education', 'urban', 'gender', 'engnat', 'age', 'screensize', 'uniquenetworklocation', 'hand', 'religion', 'orientation', 'race', 'voted', 'married', 'familysize', 'major']

# %%
data.describe()
# Out:
#                 Q1A           Q1I           Q1E           Q2A           Q2I  \
# count  39775.000000  39775.000000  3.977500e+04  39775.000000  39775.000000
# mean       2.619485     21.555977  6.970591e+03      2.172269     21.248070
# std        1.032117     12.133621  8.670513e+04      1.111563     12.125288
# min        1.000000      1.000000  1.800000e+02      1.000000      1.000000
# 25%        2.000000     11.000000  2.664000e+03      1.000000     11.000000
# 50%        3.000000     22.000000  3.609000e+03      2.000000     21.000000
# 75%        4.000000     32.000000  5.358000e+03      3.000000     32.000000
# max        4.000000     42.000000  1.210228e+07      4.000000     42.000000
#
#                 Q2E           Q3A           Q3I           Q3E           Q4A  \
# count  3.977500e+04  39775.000000  39775.000000  3.977500e+04  39775.000000
# mean   5.332376e+03      2.226097     21.583004  7.426446e+03      1.950170
# std    2.651361e+04      1.038526     12.115637  1.587024e+05      1.042218
# min    1.760000e+02      1.000000      1.000000 -1.081400e+04      1.000000
# 25%    2.477000e+03      1.000000     11.000000  2.857000e+03      1.000000
# 50%    3.511000e+03      2.000000     22.000000  3.898000e+03      2.000000
# 75%    5.216000e+03      3.000000     32.000000  5.766000e+03      3.000000
# max    2.161057e+06      4.000000     42.000000  2.858269e+07      4.000000
#
#        ...           age    screensize  uniquenetworklocation         hand  \
# count  ...  39775.000000  39775.000000           39775.000000  39775.00000
# mean   ...     23.612168      1.274519               1.200025      1.13516
# std    ...     21.581722      0.446277               0.400024      0.40030
# min    ...     13.000000      1.000000               1.000000      0.00000
# 25%    ...     18.000000      1.000000               1.000000      1.00000
# 50%    ...     21.000000      1.000000               1.000000      1.00000
# 75%    ...     25.000000      2.000000               1.000000      1.00000
# max    ...   1998.000000      2.000000               2.000000      3.00000
#
#            religion   orientation          race         voted       married  \
# count  39775.000000  39775.000000  39775.000000  39775.000000  39775.000000
# mean       7.555852      1.642992     31.312885      1.705795      1.159547
# std        3.554395      1.351362     25.871272      0.473388      0.445882
# min        0.000000      0.000000     10.000000      0.000000      0.000000
# 25%        4.000000      1.000000     10.000000      1.000000      1.000000
# 50%       10.000000      1.000000     10.000000      2.000000      1.000000
# 75%       10.000000      2.000000     60.000000      2.000000      1.000000
# max       12.000000      5.000000     70.000000      2.000000      3.000000
#
#          familysize
# count  39775.000000
# mean       3.510270
# std        2.141518
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max      133.000000
#
# [8 rows x 170 columns]

# %%
droplist = []
for i in range(1,42):
    droplist.append(f'Q{i}I')
    droplist.append(f'Q{i}E')

# %%
depression = data.drop(droplist, axis = 1)
missing = depression.isna().sum()

# %%
print(missing[missing>0])
# Out:
# country        2
# major      11403
# dtype: int64

# %%
#Some of the ages are greater than 100, so let's get rid of those from the dataset.
depression = depression[depression['age'] <=100]

# %%
personality_qs = ['TIPI1', 'TIPI2', 'TIPI3', 'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10']
word_qs = ['VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6', 'VCL7', 'VCL8', 'VCL9', 'VCL10', 'VCL11', 'VCL12', 'VCL13', 'VCL14', 'VCL15', 'VCL16']
demographic_qs = ['education', 'urban', 'gender', 'engnat', 'age', 'hand', 'religion', 'orientation', 'race', 'voted', 'married', 'familysize', 'major']
technical_qs = ['screensize', 'uniquenetworklocation', 'country', 'source']

# %%
depression[personality_qs].hist(figsize = (20, 8))
depression[word_qs].hist(figsize = (20, 8))
depression[demographic_qs].hist(figsize = (20, 8))
depression[technical_qs].hist(figsize = (20, 8))
# Out:
# array([[<AxesSubplot:title={'center':'screensize'}>,
#         <AxesSubplot:title={'center':'uniquenetworklocation'}>],
#        [<AxesSubplot:title={'center':'source'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#Drop respondents who said they knew what a made up word meant
depression = depression[depression.VCL6 != 1]
depression = depression[depression.VCL9 != 1]
depression = depression[depression.VCL12 != 1]
depression[word_qs].hist(figsize = (20, 8))
# Out:
# array([[<AxesSubplot:title={'center':'VCL1'}>,
#         <AxesSubplot:title={'center':'VCL2'}>,
#         <AxesSubplot:title={'center':'VCL3'}>,
#         <AxesSubplot:title={'center':'VCL4'}>],
#        [<AxesSubplot:title={'center':'VCL5'}>,
#         <AxesSubplot:title={'center':'VCL6'}>,
#         <AxesSubplot:title={'center':'VCL7'}>,
#         <AxesSubplot:title={'center':'VCL8'}>],
#        [<AxesSubplot:title={'center':'VCL9'}>,
#         <AxesSubplot:title={'center':'VCL10'}>,
#         <AxesSubplot:title={'center':'VCL11'}>,
#         <AxesSubplot:title={'center':'VCL12'}>],
#        [<AxesSubplot:title={'center':'VCL13'}>,
#         <AxesSubplot:title={'center':'VCL14'}>,
#         <AxesSubplot:title={'center':'VCL15'}>,
#         <AxesSubplot:title={'center':'VCL16'}>]], dtype=object)

# %%
depression['depression_score'] = depression[qlist].sum(axis = 1)
depression['depression_rating'] = depression['depression_score'] / (42*4)
depression.head()
# Out:
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  \
# 36565    3    2    1    1    1    2    2    2    2     1  ...
# 25808    4    2    2    1    2    3    1    2    2     2  ...
# 21902    1    1    1    1    1    1    1    1    2     1  ...
# 7102     3    3    2    3    2    2    3    4    4     2  ...
# 3507     1    2    1    2    2    1    1    2    2     3  ...
#
#        uniquenetworklocation          hand           religion   orientation  \
# 36565                      1  right_handed           Agnostic  Heterosexual
# 25808                      1  right_handed  Christian (Other)  Heterosexual
# 21902                      2  right_handed             Muslim  Heterosexual
# 7102                       2  right_handed             Muslim  Heterosexual
# 3507                       1  right_handed  Christian (Other)      Bisexual
#
#         race      voted             married  familysize  depression_score  \
# 36565  White      voted       never_married           5                80
# 25808  White  not_voted       never_married           2               100
# 21902  Asian  not_voted       never_married           5                51
# 7102   Asian  not_voted       never_married           2               111
# 3507   White  not_voted  previously_married           1                78
#
#        depression_rating
# 36565           0.476190
# 25808           0.595238
# 21902           0.303571
# 7102            0.660714
# 3507            0.464286
#
# [5 rows x 91 columns]

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(depression, test_size = 0.2, random_state = 69)
print('Train set size:', train_set.shape)
print('Test set size:', test_set.shape)
# Out:
# Train set size: (27660, 92)
# Test set size: (6916, 92)

# %%
#We will do several machine learning models on various categories: (1) Ten item personality inventory; (2) Demographic characteristics.
#We must do one-hot encoding on the following demographic characteristics: ['urban','gender','engnat','hand','religion','orientation','race','voted','married','major']

# %%
#This will be our categorical variables. Let's remove the variables that we can leave as numbers (education, age, family size)
demographic_qs = ['urban', 'gender', 'engnat', 'hand', 'religion', 'orientation', 'race', 'voted', 'married', 'major']

# %%
depression = train_set.copy()
corr_matrix = depression.corr()

# %%
depression_simplified = depression[['source', 'TIPI1', 'TIPI2', 'TIPI3', 'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 
'TIPI9', 'TIPI10', 'education', 'gender', 'engnat', 'age', 'screensize', 'uniquenetworklocation', 'hand', 'orientation', 'voted', 'married', 
'familysize', 'depression_rating']]

# %%
corr_matrix_simplified = depression_simplified.corr()

# %%
#train_set[demographic_qs].hist(figsize = (20,15))

# %%
sns.set_theme(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix_simplified, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 8))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_matrix_simplified, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(corr_matrix['depression_score'].sort_values(ascending = False).head(20))
# Out:
#                    depression_score
# depression_score           1.000000
# depression_rating          1.000000
# Q13A                       0.770954
# Q34A                       0.744547
# Q21A                       0.741662
# Q26A                       0.738553
# Q17A                       0.737489
# Q38A                       0.726350
# Q11A                       0.722071
# Q36A                       0.718826
# Q3A                        0.715975
# Q10A                       0.715051
# Q5A                        0.713433
# Q1A                        0.710306
# Q16A                       0.709960
# Q24A                       0.705550
# Q29A                       0.705290
# Q33A                       0.704585
# Q20A                       0.704074
# Q8A                        0.703525

# %%
from pandas.plotting import scatter_matrix
attributes = ['depression_score', 'age', 'familysize']
scatter_matrix(depression[attributes], figsize = (13, 8))
# Out:
# array([[<AxesSubplot:xlabel='depression_score', ylabel='depression_score'>,
#         <AxesSubplot:xlabel='age', ylabel='depression_score'>,
#         <AxesSubplot:xlabel='familysize', ylabel='depression_score'>],
#        [<AxesSubplot:xlabel='depression_score', ylabel='age'>,
#         <AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='familysize', ylabel='age'>],
#        [<AxesSubplot:xlabel='depression_score', ylabel='familysize'>,
#         <AxesSubplot:xlabel='age', ylabel='familysize'>,
#         <AxesSubplot:xlabel='familysize', ylabel='familysize'>]],
#       dtype=object)

# %%
#The two continuous demographic characteristics don't appear to be correlated with depression score. 
#Next, let's separate the predictors and the labels and do one-hot encoding

# %%
depression.head()
# Out:
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  hand  religion  \
# 5025     2    1    1    1    1    2    1    1    2     1  ...     1        10
# 36565    3    2    1    1    1    2    2    2    2     1  ...     1         1
# 25808    4    2    2    1    2    3    1    2    2     2  ...     1         7
# 21902    1    1    1    1    1    1    1    1    2     1  ...     1        10
# 7102     3    3    2    3    2    2    3    4    4     2  ...     1        10
#
#        orientation  race  voted  married  familysize            major  \
# 5025             0    70      2        1           4              NaN
# 36565            1    60      1        1           5      Criminology
# 25808            1    60      2        1           2              NaN
# 21902            1    10      2        1           5     Engineering
# 7102             1    10      2        1           2  Islamic Finance
#
#        depression_score  depression_rating
# 5025                 64           0.380952
# 36565                80           0.476190
# 25808               100           0.595238
# 21902                51           0.303571
# 7102                111           0.660714
#
# [5 rows x 92 columns]

# %%
depression.isna().sum().sort_values(ascending = False)
# Out:
# major                7692
# country                 1
# Q1A                     0
# TIPI10                  0
# VCL8                    0
#                      ...
# Q29A                    0
# Q28A                    0
# Q27A                    0
# Q26A                    0
# depression_rating       0
# Length: 92, dtype: int64

# %%
#Let's drop the missing country, and leave the missing values for major
depression.dropna(subset = ['country'], inplace = True)
depression.isna().sum().sort_values(ascending = False)
# Out:
# major                7691
# Q1A                     0
# TIPI9                   0
# VCL8                    0
# VCL7                    0
#                      ...
# Q29A                    0
# Q28A                    0
# Q27A                    0
# Q26A                    0
# depression_rating       0
# Length: 92, dtype: int64

# %%
depression['urban'].replace({1: 'rural', 2: 'suburban', 3: 'urban'}, inplace = True)
depression['gender'].replace({1: 'male', 2: 'female', 3: 'other_gender'}, inplace = True)
depression['engnat'].replace({1: 'english_native', 2: 'not_english_native'}, inplace = True)
depression['hand'].replace({1: 'right_handed', 2: 'left_handed', 3: 'both_handed'}, inplace = True)
depression['religion'].replace({1:'Agnostic', 2:'Atheist', 3:'Buddhist', 4:'Christian (Catholic)', 5:'Christian (Mormon)', 6:'Christian (Protestant)', 
            7:'Christian (Other)', 8:'Hindu', 9:'Jewish', 10:'Muslim', 11:'Sikh', 12:'Other_religion'}, inplace = True)
depression['orientation'].replace({1:'Heterosexual', 2:'Bisexual', 3:'Homosexual', 4:'Asexual', 5:'Other_orientation'}, inplace = True)
depression['race'].replace({10:'Asian', 20:'Arab', 30:'Black', 40:'Indigenous Australian', 50:'Native American', 60:'White', 70:'Other_race'}, inplace = True)
depression['voted'].replace({1: 'voted', 2: 'not_voted',}, inplace = True)
depression['married'].replace({1: 'never_married', 2: 'married', 3: 'previously_married'}, inplace = True)

# %%
depression.head()
# Out:
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...          hand  \
# 5025     2    1    1    1    1    2    1    1    2     1  ...  right_handed
# 36565    3    2    1    1    1    2    2    2    2     1  ...  right_handed
# 25808    4    2    2    1    2    3    1    2    2     2  ...  right_handed
# 21902    1    1    1    1    1    1    1    1    2     1  ...  right_handed
# 7102     3    3    2    3    2    2    3    4    4     2  ...  right_handed
#
#                 religion   orientation        race      voted        married  \
# 5025              Muslim             0  Other_race  not_voted  never_married
# 36565           Agnostic  Heterosexual       White      voted  never_married
# 25808  Christian (Other)  Heterosexual       White  not_voted  never_married
# 21902             Muslim  Heterosexual       Asian  not_voted  never_married
# 7102              Muslim  Heterosexual       Asian  not_voted  never_married
#
#        familysize            major  depression_score  depression_rating
# 5025            4              NaN                64           0.380952
# 36565           5      Criminology                80           0.476190
# 25808           2              NaN               100           0.595238
# 21902           5     Engineering                 51           0.303571
# 7102            2  Islamic Finance               111           0.660714
#
# [5 rows x 92 columns]

# %%
depression_modified = depression.copy()

# %%
depression['major'].value_counts().sort_values(ascending = False).head(20)
# Out:
# English              711
# Psychology           586
# Business             459
# Accounting           457
# Engineering          412
# psychology           400
# Law                  377
# Science              244
# Medicine             229
# engineering          222
# Biology              215
# Computer Science     185
# Education            185
# Nursing              178
# Psychology           178
# Civil engineering    158
# Finance              156
# IT                   141
# Management           138
# Medical              133
# Name: major, dtype: int64

# %%
#Let's drop the major column for now, since there are too many values. May re-evaluate just the top values later
depression = depression.drop('major', axis = 1)

# %%
demographic_qs = ['urban',
 'gender',
 'engnat',
 'hand',
 'religion',
 'orientation',
 'race',
 'voted',
 'married']

# %%
#Get rid of demographic qs that have a '0' in them, since they aren't associated with a value we know
def filter_rows_by_values(df, cols, values):
    for col in cols:
        print(col)
        df = df[~df[col].isin(values)]
    return df

depression = filter_rows_by_values(depression, demographic_qs, values = [0])
depression.head()
# Out:
# urban
# gender
# engnat
# hand
# religion
# orientation
# race
# voted
# married
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  \
# 36565    3    2    1    1    1    2    2    2    2     1  ...
# 25808    4    2    2    1    2    3    1    2    2     2  ...
# 21902    1    1    1    1    1    1    1    1    2     1  ...
# 7102     3    3    2    3    2    2    3    4    4     2  ...
# 3507     1    2    1    2    2    1    1    2    2     3  ...
#
#        uniquenetworklocation          hand           religion   orientation  \
# 36565                      1  right_handed           Agnostic  Heterosexual
# 25808                      1  right_handed  Christian (Other)  Heterosexual
# 21902                      2  right_handed             Muslim  Heterosexual
# 7102                       2  right_handed             Muslim  Heterosexual
# 3507                       1  right_handed  Christian (Other)      Bisexual
#
#         race      voted             married  familysize  depression_score  \
# 36565  White      voted       never_married           5                80
# 25808  White  not_voted       never_married           2               100
# 21902  Asian  not_voted       never_married           5                51
# 7102   Asian  not_voted       never_married           2               111
# 3507   White  not_voted  previously_married           1                78
#
#        depression_rating
# 36565           0.476190
# 25808           0.595238
# 21902           0.303571
# 7102            0.660714
# 3507            0.464286
#
# [5 rows x 91 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
categories = depression[['urban','gender','engnat','hand','religion','orientation','race','voted','married']]
cat_encoder = OneHotEncoder()
depression_cat_1hot = cat_encoder.fit_transform(categories)

# %%
cat_encoder.categories_
# Out:
# [array(['rural', 'suburban', 'urban'], dtype=object),
#  array(['female', 'male', 'other_gender'], dtype=object),
#  array(['english_native', 'not_english_native'], dtype=object),
#  array(['both_handed', 'left_handed', 'right_handed'], dtype=object),
#  array(['Agnostic', 'Atheist', 'Buddhist', 'Christian (Catholic)',
#         'Christian (Mormon)', 'Christian (Other)',
#         'Christian (Protestant)', 'Hindu', 'Jewish', 'Muslim',
#         'Other_religion', 'Sikh'], dtype=object),
#  array(['Asexual', 'Bisexual', 'Heterosexual', 'Homosexual',
#         'Other_orientation'], dtype=object),
#  array(['Arab', 'Asian', 'Black', 'Indigenous Australian',
#         'Native American', 'Other_race', 'White'], dtype=object),
#  array(['not_voted', 'voted'], dtype=object),
#  array(['married', 'never_married', 'previously_married'], dtype=object)]

# %%
depression.columns
# Out:
# Index(['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A', 'Q7A', 'Q8A', 'Q9A', 'Q10A',
#        'Q11A', 'Q12A', 'Q13A', 'Q14A', 'Q15A', 'Q16A', 'Q17A', 'Q18A', 'Q19A',
#        'Q20A', 'Q21A', 'Q22A', 'Q23A', 'Q24A', 'Q25A', 'Q26A', 'Q27A', 'Q28A',
#        'Q29A', 'Q30A', 'Q31A', 'Q32A', 'Q33A', 'Q34A', 'Q35A', 'Q36A', 'Q37A',
#        'Q38A', 'Q39A', 'Q40A', 'Q41A', 'Q42A', 'Q42I', 'Q42E', 'country',
#        'source', 'introelapse', 'testelapse', 'surveyelapse', 'TIPI1', 'TIPI2',
#        'TIPI3', 'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
#        'VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6', 'VCL7', 'VCL8', 'VCL9',
#        'VCL10', 'VCL11', 'VCL12', 'VCL13', 'VCL14', 'VCL15', 'VCL16',
#        'education', 'urban', 'gender', 'engnat', 'age', 'screensize',
#        'uniquenetworklocation', 'hand', 'religion', 'orientation', 'race',
#        'voted', 'married', 'familysize', 'depression_score',
#        'depression_rating'],
#       dtype='object')

# %%
depression_rating = depression['depression_rating'].copy()
depression = depression.drop(['depression_score', 'depression_rating'], axis = 1)

# %%
depression_num_attribs = ['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A', 'Q7A', 'Q8A', 'Q9A', 'Q10A',
       'Q11A', 'Q12A', 'Q13A', 'Q14A', 'Q15A', 'Q16A', 'Q17A', 'Q18A', 'Q19A',
       'Q20A', 'Q21A', 'Q22A', 'Q23A', 'Q24A', 'Q25A', 'Q26A', 'Q27A', 'Q28A',
       'Q29A', 'Q30A', 'Q31A', 'Q32A', 'Q33A', 'Q34A', 'Q35A', 'Q36A', 'Q37A',
       'Q38A', 'Q39A', 'Q40A', 'Q41A', 'Q42A', 'Q42I', 'Q42E', 'TIPI1', 'TIPI2',
       'TIPI3', 'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
       'VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6', 'VCL7', 'VCL8', 'VCL9',
       'VCL10', 'VCL11', 'VCL12', 'VCL13', 'VCL14', 'VCL15', 'VCL16',
       'education', 'age', 'familysize']

# %%
depression_num = depression[depression_num_attribs]

# %%
#Create a data pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

cat_attribs = demographic_qs

num_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

depression_num_tr = num_pipeline.fit_transform(depression_num)

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, depression_num_attribs),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs)
])

depression_prepared = full_pipeline.fit_transform(depression)

# %%
depression_prepared
# Out:
# array([[ 0.37822405, -0.13862801, -1.17377905, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.35078885, -0.13862801, -0.20579755, ...,  0.        ,
#          1.        ,  0.        ],
#        [-1.56690556, -1.04276531, -1.17377905, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 1.35078885,  1.66964661,  1.73016546, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.35078885,  0.7655093 , -0.20579755, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.59434076, -0.13862801,  0.76218395, ...,  0.        ,
#          1.        ,  0.        ]])

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(depression_prepared, depression_rating)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
dep_predictions =linreg.predict(depression_prepared)
lin_rmse = mean_squared_error(depression_rating, dep_predictions, squared = False)
lin_rmse
# Out:
# 3.762155992015533e-16

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(depression_rating, dep_predictions)
mae
# Out:
# 3.1347686346308876e-16

# %%
some_data = depression.iloc[:10]
some_values = depression_rating.iloc[:10]
some_data_prepared = full_pipeline.transform(some_data)

# %%
linreg.predict(some_data_prepared)
# Out:
# array([0.47619048, 0.5952381 , 0.30357143, 0.66071429, 0.46428571,
#        0.55357143, 0.86904762, 0.54761905, 0.94642857, 0.41666667])

# %%
print(f'Predictions: {linreg.predict(some_data_prepared)}')
print(f'Actuals: {list(some_values)}')
# Out:
# Predictions: [0.47619048 0.5952381  0.30357143 0.66071429 0.46428571 0.55357143
#  0.86904762 0.54761905 0.94642857 0.41666667]
# Actuals: [0.47619047619047616, 0.5952380952380952, 0.30357142857142855, 0.6607142857142857, 0.4642857142857143, 0.5535714285714286, 0.8690476190476191, 0.5476190476190477, 0.9464285714285714, 0.4166666666666667]

# %%
#The predictions are so precise, we may have an overfitting problem. Solutions for overfitting are: (1) Simplify the model; (2) Constrain it (regularize it); (3) Get a lot more training data.
#We need to use part of the training set for training, and part of it for validation using cross_val_score.

# %%
from sklearn.tree import DecisionTreeRegressor
dep_tree = DecisionTreeRegressor()
dep_tree.fit(depression_prepared, depression_rating)

dep_predictions = dep_tree.predict(depression_prepared)
tree_rmse = mean_squared_error(depression_rating, dep_predictions, squared = False)
tree_rmse
# Out:
# 8.826614731918974e-18

# %%
#Again, we have a small rmse. We should simplify the model and validate the model on the training data.
depression_num_attribs_simplified = ['TIPI1', 'TIPI2',
       'TIPI3', 'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
       'VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6', 'VCL7', 'VCL8', 'VCL9',
       'VCL10', 'VCL11', 'VCL12', 'VCL13', 'VCL14', 'VCL15', 'VCL16',
       'education', 'age', 'familysize']

cat_attribs = demographic_qs

num_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, depression_num_attribs_simplified),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs)
])

depression_prepared = full_pipeline.fit_transform(depression)


#Linear regression
linreg = LinearRegression()
linreg.fit(depression_prepared, depression_rating)

#Now, get the rmse
dep_predictions =linreg.predict(depression_prepared)
lin_rmse = mean_squared_error(depression_rating, dep_predictions, squared = False)
lin_rmse
# Out:
# 0.13200207534066036

# %%
depression_prepared.shape
# Out:
# (24562, 69)

# %%
#The model is not overfitting now. As the depression score is from 0 to 1, this is not too bad. Let's try the decision tree.
dep_tree = DecisionTreeRegressor()
dep_tree.fit(depression_prepared, depression_rating)

dep_predictions = dep_tree.predict(depression_prepared)
tree_rmse = mean_squared_error(depression_rating, dep_predictions, squared = False)
tree_rmse
# Out:
# 1.6231476151540286e-18

# %%
#The decision tree RMSE is still 0, showing overfitting.
from sklearn.model_selection import cross_val_score

scores = cross_val_score(dep_tree, depression_prepared, depression_rating, scoring = 'neg_mean_squared_error', cv = 10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print('scores:', scores)
    print('mean:', scores.mean())
    print('standard deviation:', scores.std())

display_scores(tree_rmse_scores)
# Out:
# scores: [0.1824104  0.18383775 0.1841489  0.18424786 0.17984686 0.18420084
#  0.19015927 0.18107826 0.18217754 0.1860707 ]
# mean: 0.1838178377556619
# standard deviation: 0.002714334718595126

# %%
#Using folds, our scores worsened. Let's try random forests
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor(max_features='sqrt')
forest_reg.fit(depression_prepared, depression_rating)
dep_tree_predictions = forest_reg.predict(depression_prepared)
forest_rmse = mean_squared_error(depression_rating, dep_tree_predictions, squared = False)
forest_rmse
# Out:
# 0.048003903445786006

# %%
results = pd.DataFrame({'Predicted': dep_tree_predictions[:10].tolist(), 'Actual': depression_rating[:10].tolist()})
results['Error'] = abs(results['Predicted'] - results['Actual'])/results['Actual']
results.style.format({'Error': '{:,.2%}'.format,})
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e042_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Predicted</th>
#       <th class="col_heading level0 col1" >Actual</th>
#       <th class="col_heading level0 col2" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e042_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e042_row0_col0" class="data row0 col0" >0.507619</td>
#       <td id="T_5e042_row0_col1" class="data row0 col1" >0.476190</td>
#       <td id="T_5e042_row0_col2" class="data row0 col2" >6.60%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e042_row1_col0" class="data row1 col0" >0.609464</td>
#       <td id="T_5e042_row1_col1" class="data row1 col1" >0.595238</td>
#       <td id="T_5e042_row1_col2" class="data row1 col2" >2.39%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e042_row2_col0" class="data row2 col0" >0.359167</td>
#       <td id="T_5e042_row2_col1" class="data row2 col1" >0.303571</td>
#       <td id="T_5e042_row2_col2" class="data row2 col2" >18.31%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e042_row3_col0" class="data row3 col0" >0.675952</td>
#       <td id="T_5e042_row3_col1" class="data row3 col1" >0.660714</td>
#       <td id="T_5e042_row3_col2" class="data row3 col2" >2.31%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e042_row4_col0" class="data row4 col0" >0.528929</td>
#       <td id="T_5e042_row4_col1" class="data row4 col1" >0.464286</td>
#       <td id="T_5e042_row4_col2" class="data row4 col2" >13.92%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e042_row5_col0" class="data row5 col0" >0.548929</td>
#       <td id="T_5e042_row5_col1" class="data row5 col1" >0.553571</td>
#       <td id="T_5e042_row5_col2" class="data row5 col2" >0.84%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e042_row6_col0" class="data row6 col0" >0.786786</td>
#       <td id="T_5e042_row6_col1" class="data row6 col1" >0.869048</td>
#       <td id="T_5e042_row6_col2" class="data row6 col2" >9.47%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e042_row7_col0" class="data row7 col0" >0.555952</td>
#       <td id="T_5e042_row7_col1" class="data row7 col1" >0.547619</td>
#       <td id="T_5e042_row7_col2" class="data row7 col2" >1.52%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e042_row8_col0" class="data row8 col0" >0.870536</td>
#       <td id="T_5e042_row8_col1" class="data row8 col1" >0.946429</td>
#       <td id="T_5e042_row8_col2" class="data row8 col2" >8.02%</td>
#     </tr>
#     <tr>
#       <th id="T_5e042_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e042_row9_col0" class="data row9 col0" >0.418750</td>
#       <td id="T_5e042_row9_col1" class="data row9 col1" >0.416667</td>
#       <td id="T_5e042_row9_col2" class="data row9 col2" >0.50%</td>
#     </tr>
#   </tbody>
# </table>

# %%
importances = forest_reg.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest_reg.estimators_], axis = 0)

# %%
len(importances)
# Out:
# 69

# %%
cat_categories = []
for items in cat_encoder.categories_:
    for item in items:
        cat_categories.append(item)

# %%
cat_encoder = full_pipeline.named_transformers_['cat']
cat_one_hot_attribs = list(cat_categories)

attributes = depression_num_attribs_simplified + cat_one_hot_attribs
forest_importances = pd.Series(importances, index = attributes)

# %%
forest_importances.plot.bar(yerr = std, figsize = (20, 5))
# Out:
# <AxesSubplot:>

# %%
forest_importances_df = pd.DataFrame(sorted(zip(importances, attributes), reverse=True), columns = ['Importance', 'Feature'])

# %%
forest_importances_df
# Out:
#     Importance                Feature
# 0     0.199791                  TIPI4
# 1     0.133447                  TIPI9
# 2     0.052303                  TIPI8
# 3     0.047578                    age
# 4     0.040996                  TIPI6
# ..         ...                    ...
# 64    0.000384                   Sikh
# 65    0.000116  Indigenous Australian
# 66    0.000000                   VCL9
# 67    0.000000                   VCL6
# 68    0.000000                  VCL12
#
# [69 rows x 2 columns]

# %%
plt.figure(figsize = (20, 8))
ax = sns.barplot(x = forest_importances_df['Feature'], y = forest_importances_df['Importance'], yerr = std)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45)
plt.show()

# %%
#As we can see, two personality index questions greatly influence the depression rating.

# %%
train_set.head()
# Out:
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  hand  religion  \
# 5025     2    1    1    1    1    2    1    1    2     1  ...     1        10
# 36565    3    2    1    1    1    2    2    2    2     1  ...     1         1
# 25808    4    2    2    1    2    3    1    2    2     2  ...     1         7
# 21902    1    1    1    1    1    1    1    1    2     1  ...     1        10
# 7102     3    3    2    3    2    2    3    4    4     2  ...     1        10
#
#        orientation  race  voted  married  familysize            major  \
# 5025             0    70      2        1           4              NaN
# 36565            1    60      1        1           5      Criminology
# 25808            1    60      2        1           2              NaN
# 21902            1    10      2        1           5     Engineering
# 7102             1    10      2        1           2  Islamic Finance
#
#        depression_score  depression_rating
# 5025                 64           0.380952
# 36565                80           0.476190
# 25808               100           0.595238
# 21902                51           0.303571
# 7102                111           0.660714
#
# [5 rows x 92 columns]

# %%
train_set.columns
# Out:
# Index(['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A', 'Q7A', 'Q8A', 'Q9A', 'Q10A',
#        'Q11A', 'Q12A', 'Q13A', 'Q14A', 'Q15A', 'Q16A', 'Q17A', 'Q18A', 'Q19A',
#        'Q20A', 'Q21A', 'Q22A', 'Q23A', 'Q24A', 'Q25A', 'Q26A', 'Q27A', 'Q28A',
#        'Q29A', 'Q30A', 'Q31A', 'Q32A', 'Q33A', 'Q34A', 'Q35A', 'Q36A', 'Q37A',
#        'Q38A', 'Q39A', 'Q40A', 'Q41A', 'Q42A', 'Q42I', 'Q42E', 'country',
#        'source', 'introelapse', 'testelapse', 'surveyelapse', 'TIPI1', 'TIPI2',
#        'TIPI3', 'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
#        'VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6', 'VCL7', 'VCL8', 'VCL9',
#        'VCL10', 'VCL11', 'VCL12', 'VCL13', 'VCL14', 'VCL15', 'VCL16',
#        'education', 'urban', 'gender', 'engnat', 'age', 'screensize',
#        'uniquenetworklocation', 'hand', 'religion', 'orientation', 'race',
#        'voted', 'married', 'familysize', 'major', 'depression_score',
#        'depression_rating'],
#       dtype='object')

# %% [markdown]
# Let's look at some violin plots to see whether we can tell visually whether there is a correlation between the features and the depression rating

# %%
fig, axes = plt.subplots(3, 3, figsize = (20, 15))
for i, ax in enumerate(axes.ravel()):
    sns.violinplot(data = depression_modified, x = demographic_qs[i], y = 'depression_rating', ax = ax)
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 50)
plt.tight_layout()

# %%
len(personality_qs)
# Out:
# 10

# %%
fig, axes = plt.subplots(2, 5, figsize = (30, 8))
for i, ax in enumerate(axes.ravel()):
    sns.violinplot(data = depression_modified, x = personality_qs[i], y = 'depression_rating', ax = ax)
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 50)
plt.tight_layout()

# %% [markdown]
# Now let's evaulate model on the test set

# %%
test_set.head()
# Out:
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  hand  religion  \
# 16603    2    1    2    2    2    1    1    3    4     2  ...     1        10
# 39194    2    4    2    1    2    1    1    2    2     2  ...     1         4
# 790      4    1    2    2    2    4    1    2    4     1  ...     2         6
# 31999    4    3    3    4    4    4    4    4    4     4  ...     1        10
# 2942     3    2    1    2    2    3    1    3    2     3  ...     1         1
#
#        orientation  race  voted  married  familysize                  major  \
# 16603            1    10      2        1           3       Computer Science
# 39194            1    10      2        1           3                Medical
# 790              1    30      2        1           4               Medicine
# 31999            1    70      2        1           3                    Law
# 2942             1    60      2        1           3  Physics and Chemistry
#
#        depression_score  depression_rating
# 16603                88           0.523810
# 39194                85           0.505952
# 790                 102           0.607143
# 31999               165           0.982143
# 2942                102           0.607143
#
# [5 rows x 92 columns]

# %%
test_set['urban'].replace({1: 'rural', 2: 'suburban', 3: 'urban'}, inplace = True)
test_set['gender'].replace({1: 'male', 2: 'female', 3: 'other_gender'}, inplace = True)
test_set['engnat'].replace({1: 'english_native', 2: 'not_english_native'}, inplace = True)
test_set['hand'].replace({1: 'right_handed', 2: 'left_handed', 3: 'both_handed'}, inplace = True)
test_set['religion'].replace({1:'Agnostic', 2:'Atheist', 3:'Buddhist', 4:'Christian (Catholic)', 5:'Christian (Mormon)', 6:'Christian (Protestant)', 
            7:'Christian (Other)', 8:'Hindu', 9:'Jewish', 10:'Muslim', 11:'Sikh', 12:'Other_religion'}, inplace = True)
test_set['orientation'].replace({1:'Heterosexual', 2:'Bisexual', 3:'Homosexual', 4:'Asexual', 5:'Other_orientation'}, inplace = True)
test_set['race'].replace({10:'Asian', 20:'Arab', 30:'Black', 40:'Indigenous Australian', 50:'Native American', 60:'White', 70:'Other_race'}, inplace = True)
test_set['voted'].replace({1: 'voted', 2: 'not_voted',}, inplace = True)
test_set['married'].replace({1: 'never_married', 2: 'married', 3: 'previously_married'}, inplace = True)

# %%
x_test = test_set.drop('depression_rating', axis = 1)
x_test = x_test.drop('depression_score', axis = 1)
x_test = x_test.drop('major', axis = 1)
y_test = test_set['depression_rating'].copy()

# %%
x_test.head()
# Out:
#        Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  age  \
# 16603    2    1    2    2    2    1    1    3    4     2  ...   20
# 39194    2    4    2    1    2    1    1    2    2     2  ...   22
# 790      4    1    2    2    2    4    1    2    4     1  ...   19
# 31999    4    3    3    4    4    4    4    4    4     4  ...   21
# 2942     3    2    1    2    2    3    1    3    2     3  ...   42
#
#        screensize  uniquenetworklocation          hand  \
# 16603           1                      2  right_handed
# 39194           1                      1  right_handed
# 790             1                      1   left_handed
# 31999           1                      2  right_handed
# 2942            2                      1  right_handed
#
#                      religion   orientation        race      voted  \
# 16603                  Muslim  Heterosexual       Asian  not_voted
# 39194    Christian (Catholic)  Heterosexual       Asian  not_voted
# 790    Christian (Protestant)  Heterosexual       Black  not_voted
# 31999                  Muslim  Heterosexual  Other_race  not_voted
# 2942                 Agnostic  Heterosexual       White  not_voted
#
#              married  familysize
# 16603  never_married           3
# 39194  never_married           3
# 790    never_married           4
# 31999  never_married           3
# 2942   never_married           3
#
# [5 rows x 89 columns]

# %%
x_test_prepared = full_pipeline.transform(x_test)

# %%
final_predictions = forest_reg.predict(x_test_prepared)
final_rmse = mean_squared_error(y_test, final_predictions, squared = False)

# %%
final_mae = mean_absolute_error(y_test, final_predictions)
errors = abs(final_predictions - y_test)
mape = 100 * (errors / y_test)
accuracy = 100 - np.mean(mape)
print('Final root mean squared error:', round(final_rmse, 3))
print('Final mean absolute error:', round(final_mae, 3))
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Final root mean squared error: 0.128
# Final mean absolute error: 0.103
# Accuracy: 80.61 %.

# %%
#Compute a 95% confidence interval
from scipy import stats
confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors) - 1, loc = squared_errors.mean(), scale = stats.sem(squared_errors)))
# Out:
# array([0.12605178, 0.13030573])

# %%
#The rmse is much higher on the test set than on the training set, meaning we should do more model evaluation on the training set.
